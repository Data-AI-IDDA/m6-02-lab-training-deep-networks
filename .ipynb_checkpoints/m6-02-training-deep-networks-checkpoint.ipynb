# %% [markdown]
# ## Getting Started
#
# 1. Create a notebook called **`m6-02-training-deep-networks.ipynb`**.
# 2. Standard imports and seed:
#
# ```python
# import torch
# import torch.nn as nn
# import torch.optim as optim
# from torch.utils.data import DataLoader
# from torchvision import datasets, transforms
# import matplotlib.pyplot as plt
# import numpy as np
#
# device = "cuda" if torch.cuda.is_available() else "cpu"
# torch.manual_seed(42)
# np.random.seed(42)
# ```
#
# 3. Load Fashion-MNIST and create train/validation `DataLoader`s:
#
# ```python
# tf = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
# train_set = datasets.FashionMNIST(root="./data", train=True,  download=True, transform=tf)
# val_set   = datasets.FashionMNIST(root="./data", train=False, download=True, transform=tf)
# train_loader = DataLoader(train_set, batch_size=128, shuffle=True)
# val_loader   = DataLoader(val_set,   batch_size=256, shuffle=False)
# ```
#
# ## Tasks
#
# ### Task 1 — Train the Network
#
# You will train **one** classifier on Fashion-MNIST. Everything you need is fully specified below.
#
# **The architecture.** A four-layer fully-connected ReLU network with batch normalisation on the hidden layers and dropout on the two widest layers. Input is a flattened 28×28 grayscale image (784 features); output is 10 class logits (no softmax — `CrossEntropyLoss` includes it).
#
# | Step | Layer | Output shape | Notes |
# |---|---|---|---|
# | 0 | Input | `(B, 1, 28, 28)` | a Fashion-MNIST batch |
# | 1 | `Flatten()` | `(B, 784)` | 28·28 = 784 features |
# | 2 | `Linear(784, 256)` → `BatchNorm1d(256)` → `ReLU` → `Dropout(p=0.3)` | `(B, 256)` | widest hidden layer |
# | 3 | `Linear(256, 128)` → `BatchNorm1d(128)` → `ReLU` → `Dropout(p=0.3)` | `(B, 128)` | second hidden layer |
# | 4 | `Linear(128, 64)`  → `BatchNorm1d(64)`  → `ReLU` | `(B, 64)` | third hidden layer (no dropout here — kept narrow on purpose) |
# | 5 | `Linear(64, 10)` | `(B, 10)` | class logits |
#
# **The training-time hyperparameters.** Use exactly these values — no tuning, no comparisons, no extra variants.
#
# | Parameter | Value |
# |---|---|
# | Loss | `nn.CrossEntropyLoss()` |
# | Optimiser | `torch.optim.Adam` with `lr=1e-3`, `weight_decay=1e-4` |
# | LR schedule | `torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)` |
# | Epochs | 15 |
# | Batch size | 128 (already set in the DataLoaders above) |
# | Random seed | 42 (already set in the setup) |
# | Device | `"cuda"` if available, otherwise `"cpu"` |
#
# **What to do.**
#
# 1. Translate the architecture in the table into a PyTorch `nn.Sequential` (or a small `nn.Module` subclass — whichever you prefer) and move it to `device`. Print the model so the layers are visible in the notebook.
# 2. Build the canonical training loop. For each epoch:
#    - Set the model to `train()` mode, iterate over `train_loader`, and run the five-step inner loop (`optimizer.zero_grad()`, forward, loss, `loss.backward()`, `optimizer.step()`). Call `scheduler.step()` once at the end of the epoch.
#    - Set the model to `eval()` mode and, inside `torch.no_grad()`, compute the **average loss** and **accuracy** on both `train_loader` and `val_loader`.
#    - Append `train_loss`, `val_loss`, `train_acc`, `val_acc` to four Python lists.
# 3. Run the loop for **15 epochs**. After training, plot two figures side by side: training and validation **loss** vs epoch, and training and validation **accuracy** vs epoch. Print the **best validation accuracy** and the **epoch** at which it occurred.
# 4. In a short markdown cell (2–3 sentences), describe what your curves look like — for example, does the model still improve at epoch 15, do training and validation loss stay close together, and what is your best validation accuracy. Validation accuracy is expected to land around **89–90%** on this architecture; report whatever number you actually got.

# %%
import torch
import torchvision
from torchvision import datasets, transforms

print(torch.__version__)
print(torchvision.__version__)
print(torch.cuda.is_available())
# Out:
# 2.12.0+cu126
# 0.27.0+cu126
# True

# %% [markdown]
# # Training Deep Networks
#
# In this lab, I train a fully connected neural network on the Fashion-MNIST dataset using PyTorch.
#
# The goal is to build one complete training pipeline with:
# - mini-batch training
# - validation tracking
# - dropout
# - batch normalization
# - weight decay
# - cosine learning-rate scheduling

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

import matplotlib.pyplot as plt
import numpy as np

device = "cuda" if torch.cuda.is_available() else "cpu"

torch.manual_seed(42)
np.random.seed(42)

print("Device:", device)
# Out:
# Device: cuda

# %% [markdown]
# ## Loading Fashion-MNIST
#
# Fashion-MNIST contains 28×28 grayscale images of clothing items.
#
# Each image belongs to one of 10 classes.
# The images are converted to tensors and normalized so the pixel values are centered around 0.

# %%
tf = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

train_set = datasets.FashionMNIST(
    root="./data",
    train=True,
    download=True,
    transform=tf
)

val_set = datasets.FashionMNIST(
    root="./data",
    train=False,
    download=True,
    transform=tf
)

train_loader = DataLoader(
    train_set,
    batch_size=128,
    shuffle=True
)

val_loader = DataLoader(
    val_set,
    batch_size=256,
    shuffle=False
)

print("Train size:", len(train_set))
print("Validation size:", len(val_set))
# Out:
# Train size: 60000
# Validation size: 10000

# %% [markdown]
# ## Model Architecture
#
# The network is a fully connected MLP with:
#
# - Input: 784 features (flattened 28×28 image)
# - Hidden layers: 256 → 128 → 64
# - Batch Normalization on each hidden layer
# - Dropout on the two widest layers
# - ReLU activations
# - Output: 10 logits (for 10 classes)
#
# No softmax is used because CrossEntropyLoss applies it internally.

# %%
model = nn.Sequential(
    nn.Flatten(),                       # (B, 1, 28, 28) → (B, 784)
    
    nn.Linear(784, 256),
    nn.BatchNorm1d(256),
    nn.ReLU(),
    nn.Dropout(p=0.3),
    
    nn.Linear(256, 128),
    nn.BatchNorm1d(128),
    nn.ReLU(),
    nn.Dropout(p=0.3),
    
    nn.Linear(128, 64),
    nn.BatchNorm1d(64),
    nn.ReLU(),
    
    nn.Linear(64, 10)                  # logits (NO softmax)
).to(device)

print(model)
# Out:
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=256, bias=True)
#   (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#   (3): ReLU()
#   (4): Dropout(p=0.3, inplace=False)
#   (5): Linear(in_features=256, out_features=128, bias=True)
#   (6): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#   (7): ReLU()
#   (8): Dropout(p=0.3, inplace=False)
#   (9): Linear(in_features=128, out_features=64, bias=True)
#   (10): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#   (11): ReLU()
#   (12): Linear(in_features=64, out_features=10, bias=True)
# )

# %% [markdown]
# ## Training Setup
#
# I use:
#
# - CrossEntropyLoss (includes softmax internally)
# - Adam optimizer with weight decay
# - CosineAnnealing learning rate scheduler

# %%
criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(
    model.parameters(),
    lr=1e-3,
    weight_decay=1e-4
)

epochs = 15

scheduler = optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=epochs
)

# %% [markdown]
# ## Training Loop
#
# In each epoch, the model is trained on the training dataset using mini-batches.
#
# After training, I evaluate the model on the validation set to track its generalization performance.
#
# I record:
# - Training loss
# - Validation loss
# - Validation accuracy

# %%
# ===== TRAINING LOOP =====

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

for epoch in range(epochs):

    # TRAIN
    model.train()
    running_loss = 0
    correct_train = 0
    total_train = 0

    for X, y in train_loader:
        X, y = X.to(device), y.to(device)

        optimizer.zero_grad()
        outputs = model(X)
        loss = criterion(outputs, y)

        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        correct_train += (predicted == y).sum().item()
        total_train += y.size(0)

    train_loss = running_loss / len(train_loader)
    train_acc = correct_train / total_train

    train_losses.append(train_loss)
    train_accuracies.append(train_acc)

    # VALIDATION
    model.eval()
    val_loss = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for X, y in val_loader:
            X, y = X.to(device), y.to(device)

            outputs = model(X)
            loss = criterion(outputs, y)

            val_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            correct += (predicted == y).sum().item()
            total += y.size(0)

    val_loss /= len(val_loader)
    val_acc = correct / total

    val_losses.append(val_loss)
    val_accuracies.append(val_acc)

    scheduler.step()

    print(f"Epoch [{epoch+1}/{epochs}] "
          f"Train Loss: {train_loss:.4f} "
          f"Train Acc: {train_acc:.4f} "
          f"Val Loss: {val_loss:.4f} "
          f"Val Acc: {val_acc:.4f}")
# Out:
# Epoch [1/15] Train Loss: 0.5885 Train Acc: 0.8113 Val Loss: 0.4142 Val Acc: 0.8487
# Epoch [2/15] Train Loss: 0.4031 Train Acc: 0.8558 Val Loss: 0.3739 Val Acc: 0.8645
# Epoch [3/15] Train Loss: 0.3682 Train Acc: 0.8679 Val Loss: 0.3486 Val Acc: 0.8704
# Epoch [4/15] Train Loss: 0.3451 Train Acc: 0.8749 Val Loss: 0.3336 Val Acc: 0.8755
# Epoch [5/15] Train Loss: 0.3250 Train Acc: 0.8816 Val Loss: 0.3341 Val Acc: 0.8742
# Epoch [6/15] Train Loss: 0.3120 Train Acc: 0.8864 Val Loss: 0.3299 Val Acc: 0.8777
# Epoch [7/15] Train Loss: 0.2948 Train Acc: 0.8921 Val Loss: 0.3181 Val Acc: 0.8846
# Epoch [8/15] Train Loss: 0.2803 Train Acc: 0.8982 Val Loss: 0.3050 Val Acc: 0.8872
# Epoch [9/15] Train Loss: 0.2690 Train Acc: 0.9014 Val Loss: 0.2995 Val Acc: 0.8937
# Epoch [10/15] Train Loss: 0.2558 Train Acc: 0.9055 Val Loss: 0.2920 Val Acc: 0.8957
# Epoch [11/15] Train Loss: 0.2430 Train Acc: 0.9115 Val Loss: 0.2919 Val Acc: 0.8956
# ...

# %%
best_acc = max(val_accuracies)
best_epoch = val_accuracies.index(best_acc) + 1

print(f"Best Validation Accuracy: {best_acc:.4f} at epoch {best_epoch}")
# Out:
# Best Validation Accuracy: 0.8993 at epoch 15

# %%
plt.figure(figsize=(10, 5))

plt.plot(train_accuracies, label="Train Accuracy")
plt.plot(val_accuracies, label="Validation Accuracy")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()

plt.show()

# %% [markdown]
# ## Training Curves
#
# I plot training and validation loss curves to analyze the learning behavior of the model.

# %%
plt.figure(figsize=(10,5))

plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Validation Loss")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.title("Training vs Validation Loss")

plt.show()

# %% [markdown]
# ## Training Results Interpretation
#
# The model trained successfully for 15 epochs and reached a best validation accuracy of **89.93% at epoch 15**.
#
# The training loss decreased steadily from 0.5885 to 0.2142, and the training accuracy increased from 81.13% to 92.18%. This shows that the model learned meaningful patterns from the training data.
#
# The validation loss also decreased overall from 0.4142 to 0.2839, while validation accuracy improved from 84.87% to 89.93%. The validation curve stays reasonably close to the training curve, although there is a small gap between training and validation performance.
#
# Overall, the model shows stable learning and does not show strong signs of overfitting. The model still improves slightly toward epoch 15, but the gains become smaller in the later epochs.

# %% [markdown]
# ## Optimizer Comparison
#
# I compare three optimizers using the same model architecture:
#
# - SGD (lr=0.01, momentum=0.9)
# - Adam (lr=1e-3)
# - Adam (lr=1e-4)
#
# The goal is to observe:
# - convergence speed
# - final validation loss
# - sensitivity to learning rate

# %%
def train_model(optimizer_type, lr):
    
    model = nn.Sequential(
        nn.Flatten(),
        nn.Linear(784, 256),
        nn.BatchNorm1d(256),
        nn.ReLU(),
        nn.Dropout(0.3),
        nn.Linear(256, 128),
        nn.BatchNorm1d(128),
        nn.ReLU(),
        nn.Dropout(0.3),
        nn.Linear(128, 64),
        nn.BatchNorm1d(64),
        nn.ReLU(),
        nn.Linear(64, 10)
    ).to(device)

    criterion = nn.CrossEntropyLoss()

    if optimizer_type == "sgd":
        optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.9)
    elif optimizer_type == "adam":
        optimizer = optim.Adam(model.parameters(), lr=lr)

    val_losses = []

    for epoch in range(15):
        model.train()

        for X, y in train_loader:
            X, y = X.to(device), y.to(device)

            optimizer.zero_grad()
            outputs = model(X)
            loss = criterion(outputs, y)
            loss.backward()
            optimizer.step()

        # VALIDATION
        model.eval()
        val_loss = 0

        with torch.no_grad():
            for X, y in val_loader:
                X, y = X.to(device), y.to(device)
                outputs = model(X)
                loss = criterion(outputs, y)
                val_loss += loss.item()

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

    return val_losses

# %%
sgd_losses = train_model("sgd", 0.01)
adam_1e3_losses = train_model("adam", 1e-3)
adam_1e4_losses = train_model("adam", 1e-4)

# %%
plt.figure(figsize=(10,5))

plt.plot(sgd_losses, label="SGD (lr=0.01)")
plt.plot(adam_1e3_losses, label="Adam (lr=1e-3)")
plt.plot(adam_1e4_losses, label="Adam (lr=1e-4)")

plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.title("Optimizer Comparison")

plt.legend()
plt.show()

# %%
print("Final Losses:")
print("SGD:", sgd_losses[-1])
print("Adam (1e-3):", adam_1e3_losses[-1])
print("Adam (1e-4):", adam_1e4_losses[-1])
# Out:
# Final Losses:
# SGD: 0.3092850409448147
# Adam (1e-3): 0.30393255278468134
# Adam (1e-4): 0.3094576885923743

# %% [markdown]
# ## Optimizer Comparison — Interpretation
#
# From the validation loss results, Adam with a learning rate of 1e-3 achieved the lowest final validation loss (~0.304), making it the best-performing optimizer in this experiment.
#
# SGD with momentum (lr=0.01) performed slightly worse (~0.309), but the difference is small. This suggests that SGD is still capable of reaching a similar level of performance, although it typically converges more slowly than Adam.
#
# Adam with a lower learning rate (1e-4) resulted in the highest validation loss (~0.309). This indicates that the learning rate was too small, causing slower convergence and preventing the model from reaching optimal performance within the given number of epochs.
#
# Overall, Adam (lr=1e-3) provides the best balance between convergence speed and final performance. The comparison also shows that Adam is sensitive to the choice of learning rate, as reducing it significantly leads to worse results.
