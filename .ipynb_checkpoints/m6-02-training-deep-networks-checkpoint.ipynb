# %%
# !pip install torch torchvision
# Out:
# ...
#   Using cached torch-2.12.0-cp312-cp312-win_amd64.whl.metadata (31 kB)
# ...
#   Using cached torchvision-0.27.0-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
# Using cached torch-2.12.0-cp312-cp312-win_amd64.whl (123.0 MB)
# Using cached torchvision-0.27.0-cp312-cp312-win_amd64.whl (4.0 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# ...
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.2
#     Uninstalling sympy-1.13.2:
#       Successfully uninstalled sympy-1.13.2
# ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

device = "cuda" if torch.cuda.is_available() else "cpu"
torch.manual_seed(42)
np.random.seed(42)
print(device)
# Out:
# cpu

# %%
tf = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
train_set = datasets.FashionMNIST(root="./data", train=True,  download=True, transform=tf)
val_set   = datasets.FashionMNIST(root="./data", train=False, download=True, transform=tf)
train_loader = DataLoader(train_set, batch_size=128, shuffle=True)
val_loader   = DataLoader(val_set,   batch_size=256, shuffle=False)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 26.4M/26.4M [00:06<00:00, 3.96MB/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 29.5k/29.5k [00:00<00:00, 420kB/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 4.42M/4.42M [00:01<00:00, 2.42MB/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 5.15k/5.15k [00:00<?, ?B/s]

# %%
model = nn.Sequential(
    nn.Flatten(),

    nn.Linear(784, 256),
    nn.BatchNorm1d(256),
    nn.ReLU(),
    nn.Dropout(0.3),

    nn.Linear(256, 128),
    nn.BatchNorm1d(128),
    nn.ReLU(),
    nn.Dropout(0.3),

    nn.Linear(128, 64),
    nn.BatchNorm1d(64),
    nn.ReLU(),

    nn.Linear(64, 10)
).to(device)

print(model)
# Out:
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=256, bias=True)
#   (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#   (3): ReLU()
#   (4): Dropout(p=0.3, inplace=False)
#   (5): Linear(in_features=256, out_features=128, bias=True)
#   (6): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#   (7): ReLU()
#   (8): Dropout(p=0.3, inplace=False)
#   (9): Linear(in_features=128, out_features=64, bias=True)
#   (10): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#   (11): ReLU()
#   (12): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(
    model.parameters(),
    lr=1e-3,
    weight_decay=1e-4
)

epochs = 15

scheduler = optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=epochs
)

# %%
def evaluate(model, loader):
    model.eval()

    total_loss = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in loader:

            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)

            loss = criterion(outputs, labels)

            total_loss += loss.item()

            _, predicted = torch.max(outputs, 1)

            correct += (predicted == labels).sum().item()

            total += labels.size(0)

    avg_loss = total_loss / len(loader)
    accuracy = 100 * correct / total

    return avg_loss, accuracy

# %%
train_losses = []
val_losses = []

train_accs = []
val_accs = []

best_val_acc = 0
best_epoch = 0

for epoch in range(epochs):

    model.train()

    for images, labels in train_loader:

        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(images)

        loss = criterion(outputs, labels)

        loss.backward()

        optimizer.step()

    scheduler.step()

    train_loss, train_acc = evaluate(model, train_loader)
    val_loss, val_acc = evaluate(model, val_loader)

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    train_accs.append(train_acc)
    val_accs.append(val_acc)

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_epoch = epoch + 1

    print(
        f"Epoch [{epoch+1}/{epochs}] | "
        f"Train Loss: {train_loss:.4f} | "
        f"Val Loss: {val_loss:.4f} | "
        f"Train Acc: {train_acc:.2f}% | "
        f"Val Acc: {val_acc:.2f}%"
    )
# Out:
# Epoch [1/15] | Train Loss: 0.3648 | Val Loss: 0.3993 | Train Acc: 86.79% | Val Acc: 85.43%
# Epoch [2/15] | Train Loss: 0.3176 | Val Loss: 0.3615 | Train Acc: 88.51% | Val Acc: 86.51%
# Epoch [3/15] | Train Loss: 0.3123 | Val Loss: 0.3651 | Train Acc: 88.36% | Val Acc: 86.40%
# Epoch [4/15] | Train Loss: 0.2802 | Val Loss: 0.3391 | Train Acc: 89.69% | Val Acc: 87.47%
# Epoch [5/15] | Train Loss: 0.2624 | Val Loss: 0.3274 | Train Acc: 90.36% | Val Acc: 87.90%
# Epoch [6/15] | Train Loss: 0.2445 | Val Loss: 0.3165 | Train Acc: 91.03% | Val Acc: 88.36%
# Epoch [7/15] | Train Loss: 0.2332 | Val Loss: 0.3094 | Train Acc: 91.44% | Val Acc: 88.65%
# Epoch [8/15] | Train Loss: 0.2279 | Val Loss: 0.3147 | Train Acc: 91.63% | Val Acc: 88.67%
# Epoch [9/15] | Train Loss: 0.2108 | Val Loss: 0.3019 | Train Acc: 92.17% | Val Acc: 88.94%
# Epoch [10/15] | Train Loss: 0.1981 | Val Loss: 0.2956 | Train Acc: 92.70% | Val Acc: 89.15%
# ...

# %%
epochs_range = range(1, epochs + 1)

plt.figure(figsize=(12,5))

# Loss plot
plt.subplot(1,2,1)
plt.plot(epochs_range, train_losses, label="Train Loss")
plt.plot(epochs_range, val_losses, label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss vs Epoch")
plt.legend()

# Accuracy plot
plt.subplot(1,2,2)
plt.plot(epochs_range, train_accs, label="Train Accuracy")
plt.plot(epochs_range, val_accs, label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("Accuracy vs Epoch")
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(f"Best Validation Accuracy: {best_val_acc:.2f}%")
print(f"Achieved at Epoch: {best_epoch}")
# Out:
# Best Validation Accuracy: 89.93%
# Achieved at Epoch: 14

# %% [markdown]
# The model improved steadily during training, as the training and validation accuracy increased over the epochs while the loss decreased. The training and validation curves stayed relatively close to each other, which shows that the model generalised well and did not overfit heavily. The best validation accuracy achieved was 89.93% at epoch 14, and the model was still showing small improvements near the end of training.
